# %%
from MultiFunctions import MultiFunctions
msg=MultiFunctions()
msg.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
from MultiFunctions import MultiFunctions
msg=MultiFunctions()
msg.OddEven()
# Out:
# Enter a number: 52452
# 52452 is Even number
# (52452, 'is Even number')

# %%
from MultiFunctions import MultiFunctions
msg=MultiFunctions()
msg.Elegible()
# Out:
# Your Gender: Male
# Your Age: 20
# Not Eligible
# 'Not Eligible'

# %%
from MultiFunctions import MultiFunctions
res=MultiFunctions()
res.percentage(98,87,95,95,93)
# Out:
# 468
# 93.60000000000001
# (468, 93.60000000000001)

# %%
from MultiFunctions import MultiFunctions
res=MultiFunctions()
res.triangle(32,34,2,4,4)
# Out:
# Area of Triangle: 544.0
# Perimeter of Triangle: 10
# (544.0, 10)
