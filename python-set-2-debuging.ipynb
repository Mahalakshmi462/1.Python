# %% [raw]
# Math should lowercase as math

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
variable should be inside the function, ifoutside function use global

# %%
def my_function():
    x = 10
    x += 5
    print(x)

my_function()
# Out:
# 15

# %%
use == to compare

# %%
x = 5
if (x==10):
    print("x is 10")
else:
    print("x is not 10")
# Out:
# x is not 10

# %%
it modify numbers in original list and doesn't return value

# %%
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
return is missing

# %%
def square(n):
    x=n*n
    return x

square(4)
# Out:
# 16

# %%
Tuples are immutable and cannot modified so create new tuple

# %%
my_tuple = (1, 2, 3)
new_tuple = (1,5,3)
print(new_tuple)
# Out:
# (1, 5, 3)

# %%
placeholder is missing for integer

# %%
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name, age))
# Out:
# My name is Alice and I am 25 years old

# %%
is used for identity == check for comparison

# %%
a = [1, 2, 3]
b = [1, 2, 3]
if a==b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
for decrementing -1 step used

# %%
for i in range(5, 1,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
key is in string

# %%
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
