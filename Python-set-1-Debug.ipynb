# %%
: mising

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
concatenation doesn't done between string and int so string is converted into int

# %%
a=10
b="5"
print(a+int(b))
# Out:
# 15

# %%
: mising, missing function call

# %%
def add_numbers(a,b):
    return a+b

add_numbers(1,2)
# Out:
# 3

# %%
index error, total element is 4 imdex value is 3 but try to get 4th index which is not exist

# %%
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
 open bracket missing

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x=5/0   is undefined

# %%
x=5/1
print(x)
# Out:
# 5.0

# %%
string and int can not be added ,  so integer converted to string

# %%
name="alice"
age=25
print("Name: " + name + ",Age:" + str(age))
# Out:
# Name: alice,Age:25

# %%
for-1 step swap start and stop value for decrementing

# %%
for i in range(10,1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
= used t0 assign value, == comparison

# %%
x=10
if(x == 5):
    print("x is 5")
else:
    print("x is not 5")
# Out:
# x is not 5

# %%
functioncall mising, : miss

# %%
def greet(name):
    print("Hello," + name)

greet("Maha")
# Out:
# Hello,Maha
