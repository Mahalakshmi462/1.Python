# %%
Get input from the user
if amount is greater than 0 print positive
if amount lesser than 0 print negaive
if no transaction occur print zero

# %%
Get input from user as integer data type
convert input numbers into string to access individual digit
after convert string into int before sum
initialize the sum digit to zero
sum the int and sum digit and print the sum of digits

# %%
Get input as number from user
convert number into string and reverse it
convert string into number
display the reverse number

# %%
Get the input from the user
check the number is lesser than 2 it is not a prime number
Divide the number by 2 upto the square root of number
if it is divied it is not a prime number
if it is not divied it is a prime number

# %%
In recursive base case 0 or 1 will return 1
The given positive integer is multiply by the factorial of (n-1)
On function call each item it takes small number until it reaches base case
It back up the values and multiply it

# %%
Convert input number into string and count the string
Initialize sum is zero and convert back to number
Raise into power and sum the digits
compare the digits to original value
if its same it is a Armstrong number

# %%
if the length of string is lesser than 1 
return the original string
Identify the first, middle and last character
Concatenate the characters into last+middle+first
display the concatenated characters

# %%
Divide the decimel number by 2
Record the reminder value either 0 or 1
Replace the quotient value to the originalvalue
Repeated the division until quotient become zero
Read the Remainder into reverse order to get binary value

# %%
Read the input sentence
Remove the commas, special character from the sentence
Split the sentence into words
Return max word based on length

# %%
Read the two input strings
Remove the space and convert strings into lowercase
sort the both strings and compare each other
if it is indentical it is anagram or it is not anagram.
